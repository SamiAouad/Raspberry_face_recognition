# %%
import face_recognition
image = face_recognition.load_image_file("test.jpg")
face_locations = face_recognition.face_locations(image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 import face_recognition
#       2 image = face_recognition.load_image_file("test.jpg")
#       3 face_locations = face_recognition.face_locations(image)
#
# ModuleNotFoundError: No module named 'face_recognition'

# %%
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in d:\myapps\anaconda3\envs\iot\lib\site-packages (from face_recognition) (1.23.5)
# Requirement already satisfied: face-recognition-models>=0.3.0 in d:\myapps\anaconda3\envs\iot\lib\site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Pillow in d:\myapps\anaconda3\envs\iot\lib\site-packages (from face_recognition) (9.3.0)
# Collecting dlib>=19.7
#   Using cached dlib-19.24.0.tar.gz (3.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting Click>=6.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: colorama in d:\myapps\anaconda3\envs\iot\lib\site-packages (from Click>=6.0->face_recognition) (0.4.5)
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: dlib, Click, face_recognition
#   Running setup.py install for dlib: started
#   Running setup.py install for dlib: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [65 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   running build_ext
#   C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(cmake_version) < '3.1.0':
#   Building extension for Python 3.9.15 (main, Nov 24 2022, 14:39:17) [MSC v.1916 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\build\lib.win-amd64-cpython-39 -DPYTHON_EXECUTABLE=D:\myApps\anaconda3\envs\IOT\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\build\lib.win-amd64-cpython-39 -A x64'
#   -- Building for: Visual Studio 17 2022
#   -- Selecting Windows SDK version 10.0.19041.0 to target Windows 10.0.19044.
#   -- The C compiler identification is unknown
#   -- The CXX compiler identification is unknown
#   CMake Error at CMakeLists.txt:14 (project):
#     No CMAKE_C_COMPILER could be found.
#
#
#
#   CMake Error at CMakeLists.txt:14 (project):
#     No CMAKE_CXX_COMPILER could be found.
#
#
#
#   -- Configuring incomplete, errors occurred!
#   See also "C:/Users/pc/AppData/Local/Temp/pip-install-er0wgmiv/dlib_c1721912d9d946a0a1a784eb351521c0/build/temp.win-amd64-cpython-39/Release/CMakeFiles/CMakeOutput.log".
#   See also "C:/Users/pc/AppData/Local/Temp/pip-install-er0wgmiv/dlib_c1721912d9d946a0a1a784eb351521c0/build/temp.win-amd64-cpython-39/Release/CMakeFiles/CMakeError.log".
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py", line 222, in <module>
#       setup(
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 968, in run_commands
#       self.run_command(cmd)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 987, in run_command
#       cmd_obj.run()
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 987, in run_command
#       cmd_obj.run()
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 987, in run_command
#       cmd_obj.run()
#     File "C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py", line 134, in run
#       self.build_extension(ext)
#     File "C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py", line 171, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "D:\myApps\anaconda3\envs\IOT\lib\subprocess.py", line 373, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\pc\\AppData\\Local\\Temp\\pip-install-er0wgmiv\\dlib_c1721912d9d946a0a1a784eb351521c0\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\pc\\AppData\\Local\\Temp\\pip-install-er0wgmiv\\dlib_c1721912d9d946a0a1a784eb351521c0\\build\\lib.win-amd64-cpython-39', '-DPYTHON_EXECUTABLE=D:\\myApps\\anaconda3\\envs\\IOT\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\pc\\AppData\\Local\\Temp\\pip-install-er0wgmiv\\dlib_c1721912d9d946a0a1a784eb351521c0\\build\\lib.win-amd64-cpython-39', '-A', 'x64']' returned non-zero exit status 1.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
#   error: subprocess-exited-with-error
#
#   Running setup.py install for dlib did not run successfully.
#   exit code: 1
#
#   [69 lines of output]
#   running install
#   D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_py
#   running build_ext
#   C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(cmake_version) < '3.1.0':
#   Building extension for Python 3.9.15 (main, Nov 24 2022, 14:39:17) [MSC v.1916 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\build\lib.win-amd64-cpython-39 -DPYTHON_EXECUTABLE=D:\myApps\anaconda3\envs\IOT\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\build\lib.win-amd64-cpython-39 -A x64'
#   -- Building for: Visual Studio 17 2022
#   -- Selecting Windows SDK version 10.0.19041.0 to target Windows 10.0.19044.
#   -- The C compiler identification is unknown
#   -- The CXX compiler identification is unknown
#   CMake Error at CMakeLists.txt:14 (project):
#     No CMAKE_C_COMPILER could be found.
#
#
#
#   CMake Error at CMakeLists.txt:14 (project):
#     No CMAKE_CXX_COMPILER could be found.
#
#
#
#   -- Configuring incomplete, errors occurred!
#   See also "C:/Users/pc/AppData/Local/Temp/pip-install-er0wgmiv/dlib_c1721912d9d946a0a1a784eb351521c0/build/temp.win-amd64-cpython-39/Release/CMakeFiles/CMakeOutput.log".
#   See also "C:/Users/pc/AppData/Local/Temp/pip-install-er0wgmiv/dlib_c1721912d9d946a0a1a784eb351521c0/build/temp.win-amd64-cpython-39/Release/CMakeFiles/CMakeError.log".
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py", line 222, in <module>
#       setup(
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 968, in run_commands
#       self.run_command(cmd)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 987, in run_command
#       cmd_obj.run()
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\command\install.py", line 68, in run
#       return orig.install.run(self)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\command\install.py", line 698, in run
#       self.run_command('build')
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 987, in run_command
#       cmd_obj.run()
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\cmd.py", line 319, in run_command
#       self.distribution.run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\dist.py", line 1217, in run_command
#       super().run_command(command)
#     File "D:\myApps\anaconda3\envs\IOT\lib\site-packages\setuptools\_distutils\dist.py", line 987, in run_command
#       cmd_obj.run()
#     File "C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py", line 134, in run
#       self.build_extension(ext)
#     File "C:\Users\pc\AppData\Local\Temp\pip-install-er0wgmiv\dlib_c1721912d9d946a0a1a784eb351521c0\setup.py", line 171, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "D:\myApps\anaconda3\envs\IOT\lib\subprocess.py", line 373, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\pc\\AppData\\Local\\Temp\\pip-install-er0wgmiv\\dlib_c1721912d9d946a0a1a784eb351521c0\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\pc\\AppData\\Local\\Temp\\pip-install-er0wgmiv\\dlib_c1721912d9d946a0a1a784eb351521c0\\build\\lib.win-amd64-cpython-39', '-DPYTHON_EXECUTABLE=D:\\myApps\\anaconda3\\envs\\IOT\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\pc\\AppData\\Local\\Temp\\pip-install-er0wgmiv\\dlib_c1721912d9d946a0a1a784eb351521c0\\build\\lib.win-amd64-cpython-39', '-A', 'x64']' returned non-zero exit status 1.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# dlib
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
